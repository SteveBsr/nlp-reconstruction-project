# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

text1 = [
    "Today is our dragon boat festival, in our Chinese culture, to celebrate it with all safe and great in our lives",
    "Thank your message to show our words to the doctor, as his next contract checking, to all of us",
    "I got this message to see the approved message",
    "In fact, I have received the message from the professor, to show me, this, a couple of days ago",
    "I am very appreciated the full support of the professor, for our Springer proceedings publication."
]

text2 = [
    "During our final discuss, I told him about the new submission — the one we were waiting since last autumn, but the updates was confusing as it not included the full feedback from reviewer or maybe editor.",
    "Anyway, I believe the team, although bit delay and less communication at recent days, they really tried best for paper and cooperation.",
    "We should be grateful, I mean all of us, for the acceptance and efforts until the Springer link came finally last week, I think.",
    "Also, kindly remind me please, if the doctor still plan for the acknowledgments section edit before he sending again.",
    "Because I didn’t see that part final yet, or maybe I missed, I apologize if so.",
    "Overall, let us make sure all are safe and celebrate the outcome with strong coffee and futuretargets."
]

trans_sents1 = ["Thank your message to show our words to the doctor, like his next contract check, to all of us"]
trans_sents2 = ["Anyway, I believe the team, although bit delay and less communication at recent days, they really tried best for paper and cooperation."]

sents1 = (text1)
sents2 = (text2)

# Φορτώνουμε το embedding μοντέλο
sbert_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# Υπολογίζουμε embeddings για το text1
orig_embed1 = sbert_model.encode(sents1)
trans_embed1 = sbert_model.encode(trans_sents1)

# Υπολογίζουμε embeddings για το text2
orig_embed2 = sbert_model.encode(sents2)
trans_embed2 = sbert_model.encode(trans_sents2)

# Υπολογισμός ομοιοτήτων ανά πρόταση
print("Cosine Similarity για Text 1")
for i, (orig, trans) in enumerate(zip(orig_embed1, trans_embed1)):
    sim = cosine_similarity([orig], [trans])[0][0]
    print(f"Πρόταση {i+1}: {sim:.4f}")

print("\nCosine Similarity για Text 2")
for i, (orig, trans) in enumerate(zip(orig_embed2, trans_embed2)):
    sim = cosine_similarity([orig], [trans])[0][0]
    print(f"Πρόταση {i+1}: {sim:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 from sklearn.metrics.pairwise import cosine_similarity
#       4 text1 = [
#       5     "Today is our dragon boat festival, in our Chinese culture, to celebrate it with all safe and great in our lives",
#       6     "Thank your message to show our words to the doctor, as his next contract checking, to all of us",
#    (...)      9     "I am very appreciated the full support of the professor, for our Springer proceedings publication."
#      10 ]
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\sentence_transformers\__init__.py:9
#       6 import importlib
#       7 import os
# ----> 9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
#      14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
#      20 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\sentence_transformers\backend.py:11
#       7 from typing import TYPE_CHECKING, Callable, Literal
#       9 import huggingface_hub
# ---> 11 from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#      13 logger = logging.getLogger(__name__)
#      15 if TYPE_CHECKING:
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\sentence_transformers\util.py:17
#      15 import numpy as np
#      16 import requests
# ---> 17 import torch
#      18 from huggingface_hub import hf_hub_download, snapshot_download
#      19 from torch import Tensor, device
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\__init__.py:2240
#    2236 sys.modules.setdefault(f"{__name__}.classes", classes)
#    2238 # quantization depends on torch.fx and torch.ops
#    2239 # Import quantization
# -> 2240 from torch import quantization as quantization  # usort: skip
#    2242 # Import the quasi random sampler
#    2243 from torch import quasirandom as quasirandom  # usort: skip
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\quantization\__init__.py:2
#       1 # mypy: allow-untyped-defs
# ----> 2 from .fake_quantize import *  # noqa: F403
#       3 from .fuse_modules import fuse_modules
#       4 from .fuser_method_mappings import *  # noqa: F403
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\quantization\fake_quantize.py:10
#       1 # flake8: noqa: F401
#       2 r"""
#       3 This file is in the process of migration to `torch/ao/quantization`, and
#       4 is kept here for compatibility while the migration process is ongoing.
#    (...)      7 here.
#       8 """
# ---> 10 from torch.ao.quantization.fake_quantize import (
#      11     _is_fake_quant_script_module,
#      12     _is_per_channel,
#      13     _is_per_tensor,
#      14     _is_symmetric_quant,
#      15     default_fake_quant,
#      16     default_fixed_qparams_range_0to1_fake_quant,
#      17     default_fixed_qparams_range_neg1to1_fake_quant,
#      18     default_fused_act_fake_quant,
#      19     default_fused_per_channel_wt_fake_quant,
#      20     default_fused_wt_fake_quant,
#      21     default_histogram_fake_quant,
#      22     default_per_channel_weight_fake_quant,
#      23     default_weight_fake_quant,
#      24     disable_fake_quant,
#      25     disable_observer,
#      26     enable_fake_quant,
#      27     enable_observer,
#      28     FakeQuantize,
#      29     FakeQuantizeBase,
#      30     FixedQParamsFakeQuantize,
#      31     FusedMovingAvgObsFakeQuantize,
#      32 )
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\quantization\__init__.py:28
#      26 from .qconfig_mapping import *  # noqa: F403
#      27 from .quant_type import *  # noqa: F403
# ---> 28 from .quantization_mappings import *  # noqa: F403 # type: ignore[no-redef]
#      29 from .quantize import *  # noqa: F403
#      30 from .quantize_jit import *  # noqa: F403
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\quantization\quantization_mappings.py:18
#      14 import torch.ao.nn.quantized.reference as nnqr
#      16 # Because `torch.ao.nn` uses lazy imports, we need to make
#      17 # sure we import the contents explicitly here.
# ---> 18 import torch.ao.nn.sparse
#      19 import torch.nn.functional as F
#      20 from torch import nn
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\nn\sparse\__init__.py:1
# ----> 1 from . import quantized
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\nn\sparse\quantized\__init__.py:1
# ----> 1 from torch.ao.nn.sparse.quantized import dynamic
#       3 from .linear import Linear, LinearPackedParams
#       6 __all__ = [
#       7     "dynamic",
#       8     "Linear",
#       9     "LinearPackedParams",
#      10 ]
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\nn\sparse\quantized\dynamic\__init__.py:1
# ----> 1 from .linear import Linear
#       4 __all__ = [
#       5     "Linear",
#       6 ]
#
# File c:\Users\KYRIAKOS\AppData\Local\pypoetry\Cache\virtualenvs\nlp-reconstruction-project-2fGmCwJv-py3.12\Lib\site-packages\torch\ao\nn\sparse\quantized\dynamic\linear.py:10
#       5 import torch.ao.nn.intrinsic as nni
#       6 from torch.ao.nn.quantized.modules.utils import (
#       7     _hide_packed_params_repr,
#       8     _quantize_weight,
#       9 )
# ---> 10 from torch.ao.nn.sparse.quantized import linear
#      11 from torch.ao.nn.sparse.quantized.utils import LinearBlockSparsePattern
#      14 __all__ = ["Linear"]
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:991, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1087, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1187, in get_data(self, path)
#
# KeyboardInterrupt:
